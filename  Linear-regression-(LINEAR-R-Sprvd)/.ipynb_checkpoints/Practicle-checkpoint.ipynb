# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data.csv')

# %%
df
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
df.describe()
# Out:
#              Store  Weekly_Sales  Holiday_Flag  Temperature   Fuel_Price  \
# count  6435.000000  6.435000e+03   6435.000000  6435.000000  6435.000000
# mean     23.000000  1.046965e+06      0.069930    60.663782     3.358607
# std      12.988182  5.643666e+05      0.255049    18.444933     0.459020
# min       1.000000  2.099862e+05      0.000000    -2.060000     2.472000
# 25%      12.000000  5.533501e+05      0.000000    47.460000     2.933000
# 50%      23.000000  9.607460e+05      0.000000    62.670000     3.445000
# 75%      34.000000  1.420159e+06      0.000000    74.940000     3.735000
# max      45.000000  3.818686e+06      1.000000   100.140000     4.468000
#
#                CPI  Unemployment
# count  6435.000000   6435.000000
# mean    171.578394      7.999151
# std      39.356712      1.875885
# min     126.064000      3.879000
# 25%     131.735000      6.891000
# 50%     182.616521      7.874000
# 75%     212.743293      8.622000
# max     227.232807     14.313000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   object
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 402.3+ KB

# %%
df.columns
# Out:
# Index(['Store', 'Date', 'Weekly_Sales', 'Holiday_Flag', 'Temperature',
#        'Fuel_Price', 'CPI', 'Unemployment'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# Store           0
# Date            0
# Weekly_Sales    0
# Holiday_Flag    0
# Temperature     0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%d-%m-%Y')
df['Day']= df['Date'].dt.day
df['Month']= df['Date'].dt.month
df['Year']= df['Date'].dt.year

# %%
df.columns
# Out:
# Index(['Store', 'Date', 'Weekly_Sales', 'Holiday_Flag', 'Temperature',
#        'Fuel_Price', 'CPI', 'Unemployment', 'Day', 'Month', 'Year'],
#       dtype='object')

# %%
df
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1 2010-02-05    1643690.90             0        42.31       2.572
# 1         1 2010-02-12    1641957.44             1        38.51       2.548
# 2         1 2010-02-19    1611968.17             0        39.93       2.514
# 3         1 2010-02-26    1409727.59             0        46.63       2.561
# 4         1 2010-03-05    1554806.68             0        46.50       2.625
# ...     ...        ...           ...           ...          ...         ...
# 6430     45 2012-09-28     713173.95             0        64.88       3.997
# 6431     45 2012-10-05     733455.07             0        64.89       3.985
# 6432     45 2012-10-12     734464.36             0        54.47       4.000
# 6433     45 2012-10-19     718125.53             0        56.47       3.969
# 6434     45 2012-10-26     760281.43             0        58.85       3.882
#
#              CPI  Unemployment  Day  Month  Year
# ...

# %%
numerical_cols = ['Weekly_Sales', 'Holiday_Flag', 'Temperature', 'Fuel_Price', 'CPI', 'Unemployment']

# %%
df[numerical_cols].corr()
# Out:
#               Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price       CPI  \
# Weekly_Sales      1.000000      0.036891    -0.063810    0.009464 -0.072634
# Holiday_Flag      0.036891      1.000000    -0.155091   -0.078347 -0.002162
# Temperature      -0.063810     -0.155091     1.000000    0.144982  0.176888
# Fuel_Price        0.009464     -0.078347     0.144982    1.000000 -0.170642
# CPI              -0.072634     -0.002162     0.176888   -0.170642  1.000000
# Unemployment     -0.106176      0.010960     0.101158   -0.034684 -0.302020
#
#               Unemployment
# Weekly_Sales     -0.106176
# Holiday_Flag      0.010960
# Temperature       0.101158
# Fuel_Price       -0.034684
# CPI              -0.302020
# Unemployment      1.000000

# %% [markdown]
# Overall, correlations are weak, indicating limited linear relationships between variables. Further analysis may be required to understand any underlying patterns or causal relationships.

# %%
stores = df.groupby(by='Store')
stores['Weekly_Sales'].mean().sort_values(ascending=False)[:15].plot(kind='bar',color='black')
plt.title('Top 10 stores by Weekly_Sales')
plt.show()

# %%
def year_wise_sales(year):
    filt = df['Year'] == year
    result = df.loc[filt].groupby(by='Store')
    values = result['Weekly_Sales'].mean()
    return values 

year_2010 = year_wise_sales(2010)
year_2011 = year_wise_sales(2011)
year_2012 = year_wise_sales(2012) 

width = 0.25
x_index = np.arange(len(year_2010))

plt.figure(figsize=(15, 4))
plt.title('Sales of all stores for 3 years')
plt.bar(x_index - width, year_2010, width=width, label='2010')
plt.bar(x_index, year_2011, width=width, label='2011')
plt.bar(x_index + width, year_2012, width=width, label='2012')
plt.xticks(x_index)
plt.legend()
plt.show()

# %%
plt.title('Total sales per Year')
year_sales = df.groupby(by='Year')
year_sales['Weekly_Sales'].sum().plot(kind='bar', color='black')
plt.show()

# %%
def season(month):
    if month in [1,2,12]:
        return 'Winter'
    elif month in [3,4,5]:
        return 'Spring'
    elif month in [6,7,8]:
        return 'Summer'
    elif month in [9,10,11]:
        return 'Autumn'
    
df['Season'] = df['Month'].apply(season)

# %%
season = df.groupby(by='Season')
season['Weekly_Sales'].sum().sort_values(ascending=False).plot(kind='bar', color='black')
plt.title('Season wise Sales')
plt.show()

# %%
sns.histplot(df['Temperature'], kde=True, color='black')
# Out:
# <Axes: xlabel='Temperature', ylabel='Count'>

# %%
def whether(temp):
    if temp < 32:
        return 'Very Cold'
    elif temp > 32 and temp <50:
        return 'Cold'
    elif temp > 50 and temp< 80:
        return 'Normal'
    elif temp > 80 :
        return 'Hot'
    
df['Whether'] = df['Temperature'].apply(whether)

# %%
whether = df.groupby(by='Whether')
whether['Weekly_Sales'].mean().sort_values(ascending=False).plot(kind='bar',color='black')
plt.title('Sales for different Whether')
plt.show()

# %%
sns.kdeplot(df['Weekly_Sales'])
# Out:
# <Axes: xlabel='Weekly_Sales', ylabel='Density'>

# %%
df
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1 2010-02-05    1643690.90             0        42.31       2.572
# 1         1 2010-02-12    1641957.44             1        38.51       2.548
# 2         1 2010-02-19    1611968.17             0        39.93       2.514
# 3         1 2010-02-26    1409727.59             0        46.63       2.561
# 4         1 2010-03-05    1554806.68             0        46.50       2.625
# ...     ...        ...           ...           ...          ...         ...
# 6430     45 2012-09-28     713173.95             0        64.88       3.997
# 6431     45 2012-10-05     733455.07             0        64.89       3.985
# 6432     45 2012-10-12     734464.36             0        54.47       4.000
# 6433     45 2012-10-19     718125.53             0        56.47       3.969
# 6434     45 2012-10-26     760281.43             0        58.85       3.882
#
# ...

# %%
encoded_df = pd.get_dummies(df, columns=['Season', 'Weather'])

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

df['Season'] = label_encoder.fit_transform(df['Season'])
df['Weather'] = label_encoder.fit_transform(df['Weather'])

# %%
columns_to_drop = ['season_encoded', 'weather_encoded']
df.drop(columns=columns_to_drop, inplace=True)

# %%
df
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1 2010-02-05    1643690.90             0        42.31       2.572
# 1         1 2010-02-12    1641957.44             1        38.51       2.548
# 2         1 2010-02-19    1611968.17             0        39.93       2.514
# 3         1 2010-02-26    1409727.59             0        46.63       2.561
# 4         1 2010-03-05    1554806.68             0        46.50       2.625
# ...     ...        ...           ...           ...          ...         ...
# 6430     45 2012-09-28     713173.95             0        64.88       3.997
# 6431     45 2012-10-05     733455.07             0        64.89       3.985
# 6432     45 2012-10-12     734464.36             0        54.47       4.000
# 6433     45 2012-10-19     718125.53             0        56.47       3.969
# 6434     45 2012-10-26     760281.43             0        58.85       3.882
#
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
X = df.drop(['Weekly_Sales', 'Date'], axis=1)
y = df['Weekly_Sales']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=101)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error

rmse1 = np.sqrt(mean_squared_error(y_test, y_pred))
rmse1
# Out:
# 524843.1409824189

# %%
from sklearn.metrics import r2_score

# %%
r2 = r2_score(y_test, y_pred)
r2
# Out:
# 0.16755842696792456

# %% [markdown]
# ## Conclusion
#
# In this project, we implemented a simple linear regression model and compared its performance with a random forest regression model on our dataset. Surprisingly, the random forest model achieved a significantly higher R-squared score compared to the linear regression model.
#
# ### Insights:
#
# - The random forest model likely captures non-linear relationships and interactions between features better than the linear regression model.
# - Random forest is a more flexible model that can fit complex datasets with higher dimensionality.
# - Linear regression assumes a linear relationship between the independent and dependent variables, which may not hold true for our dataset.
# - Random forest is less sensitive to outliers and noise compared to linear regression, leading to better performance on our dataset.
#
# ### So less r2 score? WHY?
#
# - Experiment with different feature engineering techniques to improve the performance of the linear regression model.
# - Explore other regression algorithms such as support vector regression, gradient boosting, or neural networks to see if they can outperform the random forest model.
# - Conduct further analysis to identify the key features driving the predictions of the random forest model.
#
# Overall, this project highlights the importance of choosing the appropriate regression model based on the characteristics of the dataset and the underlying relationships between the variables.
